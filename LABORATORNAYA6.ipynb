# %% [markdown]
# <a href="https://colab.research.google.com/github/diesadguy/-.--311/blob/main/LABORATORNAYA6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
celsius=[[-67.0],[-34.0],[0],[34.0],[54.0],[67.0],[100]]
fahrenheit=[[-88.6],[-29.2],[32.0],[93.2],[129.2],[152.6],[212.0]]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,8), dpi=50)
plt.scatter(celsius, fahrenheit, label='входные зачения', color='green', marker='$f$');
plt.xlabel('celsius')
plt.ylabel('fahrenheit')
plt.legend()
plt.grid(True)
plt.show()

# %%
for c,f in zip(celsius,fahrenheit):
  print(f'цельсия{c}=фаренгейт{f}')
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(celsius, fahrenheit)
lr.predict([[256],[123]])
lr.coef_
lr.intercept_
celsius_test = [[-50],[10],[30],[20],[10],[70],[87]]
fahrenheit_test = lr.predict(celsius_test)
fahrenheit_test
# Out:
# цельсия[-67.0]=фаренгейт[-88.6]
# цельсия[-34.0]=фаренгейт[-29.2]
# цельсия[0]=фаренгейт[32.0]
# цельсия[34.0]=фаренгейт[93.2]
# цельсия[54.0]=фаренгейт[129.2]
# цельсия[67.0]=фаренгейт[152.6]
# цельсия[100]=фаренгейт[212.0]
# array([[-58. ],
#        [ 50. ],
#        [ 86. ],
#        [ 68. ],
#        [ 50. ],
#        [158. ],
#        [188.6]])

# %%
for c,f in zip(celsius_test,fahrenheit_test):
  print(f'цельсия{c} фаренгейт{f}')
# Out:
# цельсия[-50] фаренгейт[-58.]
# цельсия[10] фаренгейт[50.]
# цельсия[30] фаренгейт[86.]
# цельсия[20] фаренгейт[68.]
# цельсия[10] фаренгейт[50.]
# цельсия[70] фаренгейт[158.]
# цельсия[87] фаренгейт[188.6]

# %%
import numpy as np

x_range = np.arange(-70, 120)
y_range = x_range*1.8+32

plt.figure(figsize=(15,8), dpi=280)
plt.plot(x_range, y_range, label='уравнение', linewidth='1')
plt.scatter(celsius,fahrenheit, label='входные данные', color='green')
plt.scatter(celsius_test,fahrenheit_test, label='предсказанное значение', color='blue')
plt.xlabel('Цельсия')
plt.ylabel('Фаренгейта')
plt.legend()
plt.grid(True)
plt.show()

# %%
####ЭТО КУБ, ВРОДЕ ЕГО ТОЖЕ МОЖНО
x=[[3],[2],[2],[3],[3],[3.5],[3.5],[3],[3.5],[2.5],[2]]
y=[[2],[2],[3],[3],[2],[2.5],[3.5],[3],[3.5],[3.5],[3]]

import matplotlib.pyplot as plt

plt.figure(figsize=(15,15), dpi=50)
plt.plot(x, y, label='уравнение', linewidth='1')
plt.grid(True)
plt.show()

# %%
fahrenheit2 = [[-67.0],[-34.0],[0],[34.0],[54.0],[67.0],[100]]
kelvin = [[218.1],[236.5],[255.4],[274.3],[285.4],[292.6],[310.9]]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,8), dpi=50)
plt.scatter(fahrenheit2, kelvin, label='входные данные', color='green', marker='$f$');
plt.xlabel('fahrenheit')
plt.ylabel('kelvins')
plt.legend()
plt.grid(True)
plt.show()

# %%
for f,k in zip(fahrenheit2_test,kelvin_test):
  print(f'фаренгейт{f} кельвина{k}')
# Out:
# фаренгейт[-50] кельвина[227.59189163]
# фаренгейт[10] кельвина[260.93198194]
# фаренгейт[30] кельвина[272.04534537]
# фаренгейт[20] кельвина[266.48866366]
# фаренгейт[10] кельвина[260.93198194]
# фаренгейт[70] кельвина[294.27207225]
# фаренгейт[87] кельвина[303.71843117]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(fahrenheit2, kelvin)
lr.predict([[256],[123]])
lr.coef_
lr.intercept_
fahrenheit2_test = [[-50],[10],[30],[20],[10],[70],[87]]
kelvin_test = lr.predict(fahrenheit2_test)
kelvin_test
# Out:
# array([[227.59189163],
#        [260.93198194],
#        [272.04534537],
#        [266.48866366],
#        [260.93198194],
#        [294.27207225],
#        [303.71843117]])

# %%
for f,k in zip(fahrenheit2_test,kevin_test):
  print(f'фаренгейт {f} кельвин{k}')

# %%
import numpy as np
x_range = np.arrange(-70,120)
y_range = x_range*1.8+32

# %%
x_range = np.arange(-70,120)
y_range = x_range*1.8+32
plt.figure(figsize=(15,8), dpi=280)
plt.plot(x_range, y_range, label='уравнение', linewidth='1')
plt.scatter(fahrenheit2,kelvin, label='входные данные', color='green')
plt.scatter(fahrenheit2_test,kelvin_test, label='предсказанное значение', color='blue')
plt.xlabel('Фаренгейта')
plt.ylabel('Кельвина')
plt.legend()
plt.grid(True)
plt.show()
